# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pymongo
import time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.FinalProject

### vehicles and years table is populated via CSV

#db.vehicles.drop()
#db.years.drop()

# Adding SUV manually to ensure script works everywhere

#b.vehicles.insert_one(
 #   {
 #       'brand': ['acura','audi','bmw','bmw','cadillac','infiniti','landrover','lexus','lexus','lincoln','mercedesbenz','porsche','volvo'],
 #       'model': ['mdx','q5','x5','x6','escalade','qx60','range-rover','rx-350','lx-570','mkx','m-class|gle-class','cayenne','xc90']
 #   }
#)

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=True)
#url = 'https://www.edmunds.com/cadillac/xt5/2017/cost-to-own/'
#browser.visit(url)
#html = browser.html
#soup = BeautifulSoup(html, 'html.parser')
#soup = BeautifulSoup(html, 'lxml')

# %%
def scrape(url,ss):
    browser.visit(url)
    time.sleep(ss)
    html = browser.html
    #soup = BeautifulSoup(html, 'html.parser')
    soup = BeautifulSoup(html, 'lxml')
    return soup

# %%
def make_it_num(strInput):
    if(strInput):
        return strInput.replace("$","").replace(",","").strip()
    else:
        return 0

# %%
def save_car_record(detail):
    if (len(detail) > 0):
        car_year=str(detail[0])+"_final"
        car_brand=detail[1].strip()
        car_model=detail[2].strip()
        car_true_cost_own=make_it_num(detail[3].strip())
        car_cash_price=make_it_num(detail[4].strip())
        car_depreciation=[make_it_num(car_detail[i]) for i in range(6,12)]
        car_taxes=[make_it_num(car_detail[i]) for i in range(13,19)]
        car_financing=[make_it_num(car_detail[i]) for i in range(20,26)]
        car_fuel=[make_it_num(car_detail[i]) for i in range(27,33)]
        car_insurance=[make_it_num(car_detail[i]) for i in range(34,40)]
        car_maintenance=[make_it_num(car_detail[i]) for i in range(41,47)]
        car_repairs=[make_it_num(car_detail[i]) for i in range(48,54)]
        car_true_cost_5yr=[make_it_num(car_detail[i]) for i in range(55,61)]
        
        mongo_record={'year':car_year,
                       'brand':car_brand,
                       'model':car_model,
                       'owning_cost':car_true_cost_own,
                       'cash_price':car_cash_price,
                       'depreciation':car_depreciation,
                       'taxes':car_taxes,
                       'financing':car_financing,
                       'fuel':car_fuel,
                       'insurance':car_insurance,
                       'maintenance':car_maintenance,
                       'repairs':car_repairs,
                       'true_cost_5yr':car_true_cost_5yr
                     }
        #print(mongo_record)
        db[car_year].insert_one(mongo_record)
        return f"---------------------Record inserted successfully for {car_year} {car_brand} {car_model}"
        
    else:
        print("Nothing to save")

# %%
###################################### MAIN PROGRAM ########################################
########################   set below three variables to scrape data ########################
#############################################################################################
#years=db.years.find(no_cursor_timeout=True)
vs =  list(db.vehicles.find())
sleep_seconds=3
##Output variable###
## This will contain complete record as list
## where 
### Index 0 - car year
### Index 1 - brand
### Index 2 - Model
### Index 3 - true cost to own
### Index 4 - total cash price
### Index5 onward - TCO details
try:
    for year in range(2015,2019):
        c_year=str(year)
        for vehicle in vs:
            car_detail=[]
            c_brand=vehicle['urlmake']
            c_model=str(vehicle['urlmodel'])
            print(f"-----------------------------------------------Checking for {c_year} {c_brand} {c_model}")

            car_detail.append(c_year)
            car_detail.append(c_brand)
            car_detail.append(c_model)

            if(c_year=='2015' and c_brand=='porsche'):
                url='https://www.edmunds.com/porsche/cayenne/2015/st-200707125/cost-to-own/'
            else:
                url=f'https://www.edmunds.com/{c_brand}/{c_model}/{c_year}/cost-to-own/'

            print(url)

            #Finding MSRP
            try:
                soup_output=scrape(url,sleep_seconds)
                msrp_results = soup_output.find("div", class_="grid-60").find_all('ul')
                for msrp_result in msrp_results:
                    #print(msrp_result.find_all('li')[1].text.replace("$","").replace(",","")  )
                    car_detail.append(msrp_result.find_all('li')[1].text)

                #finding TCO details
                tco_results = soup_output.find('ul',id="tco_detail_data").find_all('li')
                for i in range(8,len(tco_results),8):
                    records = tco_results[i].find('ul').find_all('li')

                    for record in records:
                        #print(record.text)
                        car_detail.append(record.text)
                print(save_car_record(car_detail))

            except Exception as e:
                pass
    vs.close()            
except Exception as e:
    years.close()
    vehicles.close()
    pass
# Out:
# -----------------------------------------------Checking for 2015 chevrolet sonic
# https://www.edmunds.com/chevrolet/sonic/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet sonic
# -----------------------------------------------Checking for 2015 mitsubishi montero
# https://www.edmunds.com/mitsubishi/montero/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 scion xb
# https://www.edmunds.com/scion/xb/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final scion xb
# -----------------------------------------------Checking for 2015 hyundai accent
# https://www.edmunds.com/hyundai/accent/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai accent
# -----------------------------------------------Checking for 2015 rolls-royce phantom
# https://www.edmunds.com/rolls-royce/phantom/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 dodge challenger
# https://www.edmunds.com/dodge/challenger/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final dodge challenger
# -----------------------------------------------Checking for 2015 volkswagen jetta
# https://www.edmunds.com/volkswagen/jetta/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volkswagen jetta
# -----------------------------------------------Checking for 2015 ford focus
# https://www.edmunds.com/ford/focus/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford focus
# -----------------------------------------------Checking for 2015 dodge dart
# https://www.edmunds.com/dodge/dart/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final dodge dart
# -----------------------------------------------Checking for 2015 ford f-150
# https://www.edmunds.com/ford/f-150/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford f-150
# -----------------------------------------------Checking for 2015 toyota tundra
# https://www.edmunds.com/toyota/tundra/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota tundra
# -----------------------------------------------Checking for 2015 saturn s-series
# https://www.edmunds.com/saturn/s-series/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 nissan titan
# https://www.edmunds.com/nissan/titan/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan titan
# -----------------------------------------------Checking for 2015 kia soul
# https://www.edmunds.com/kia/soul/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia soul
# -----------------------------------------------Checking for 2015 lamborghini huracan
# https://www.edmunds.com/lamborghini/huracan/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota rav4
# https://www.edmunds.com/toyota/rav4/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota rav4
# -----------------------------------------------Checking for 2015 buick lesabre
# https://www.edmunds.com/buick/lesabre/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 fiat 500e
# https://www.edmunds.com/fiat/500e/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final fiat 500e
# -----------------------------------------------Checking for 2015 fiat 124-spider
# https://www.edmunds.com/fiat/124-spider/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 hyundai santafe
# https://www.edmunds.com/hyundai/santafe/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai santafe
# -----------------------------------------------Checking for 2015 honda ridgeline
# https://www.edmunds.com/honda/ridgeline/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 kia forte
# https://www.edmunds.com/kia/forte/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia forte
# -----------------------------------------------Checking for 2015 infiniti i35
# https://www.edmunds.com/infiniti/i35/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 infiniti q70
# https://www.edmunds.com/infiniti/q70/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final infiniti q70
# -----------------------------------------------Checking for 2015 nissan sentra
# https://www.edmunds.com/nissan/sentra/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan sentra
# -----------------------------------------------Checking for 2015 subaru outback
# https://www.edmunds.com/subaru/outback/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final subaru outback
# -----------------------------------------------Checking for 2015 genesis g90
# https://www.edmunds.com/genesis/g90/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 hyundai tucson
# https://www.edmunds.com/hyundai/tucson/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai tucson
# -----------------------------------------------Checking for 2015 jaguar f-type
# https://www.edmunds.com/jaguar/f-type/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jaguar f-type
# -----------------------------------------------Checking for 2015 toyota venza
# https://www.edmunds.com/toyota/venza/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota venza
# -----------------------------------------------Checking for 2015 audi q7
# https://www.edmunds.com/audi/q7/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final audi q7
# -----------------------------------------------Checking for 2015 mazda 3
# https://www.edmunds.com/mazda/3/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mazda 3
# -----------------------------------------------Checking for 2015 porsche 718-boxster
# https://www.edmunds.com/porsche/cayenne/2015/st-200707125/cost-to-own/
# ---------------------Record inserted successfully for 2015_final porsche 718-boxster
# -----------------------------------------------Checking for 2015 hyundai elantra
# https://www.edmunds.com/hyundai/elantra/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai elantra
# -----------------------------------------------Checking for 2015 smart fortwo
# https://www.edmunds.com/smart/fortwo/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final smart fortwo
# -----------------------------------------------Checking for 2015 maserati quattroporte
# https://www.edmunds.com/maserati/quattroporte/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 volvo v60
# https://www.edmunds.com/volvo/v60/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volvo v60
# -----------------------------------------------Checking for 2015 mercedesbenz e-class
# https://www.edmunds.com/mercedesbenz/e-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz e-class
# -----------------------------------------------Checking for 2015 maserati ghibli
# https://www.edmunds.com/maserati/ghibli/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 dodge ram-pickup-1500
# https://www.edmunds.com/dodge/ram-pickup-1500/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 jeep compass
# https://www.edmunds.com/jeep/compass/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jeep compass
# -----------------------------------------------Checking for 2015 honda civic
# https://www.edmunds.com/honda/civic/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda civic
# -----------------------------------------------Checking for 2015 hyundai sonata
# https://www.edmunds.com/hyundai/sonata/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai sonata
# -----------------------------------------------Checking for 2015 chrysler pt-cruiser
# https://www.edmunds.com/chrysler/pt-cruiser/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 chrysler pacifica-hybrid
# https://www.edmunds.com/chrysler/pacifica-hybrid/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 dodge charger
# https://www.edmunds.com/dodge/charger/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final dodge charger
# -----------------------------------------------Checking for 2015 ford fiesta
# https://www.edmunds.com/ford/fiesta/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford fiesta
# -----------------------------------------------Checking for 2015 jeep grand-cherokee
# https://www.edmunds.com/jeep/grand-cherokee/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jeep grand-cherokee
# -----------------------------------------------Checking for 2015 ram 3500
# https://www.edmunds.com/ram/3500/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ram 3500
# -----------------------------------------------Checking for 2015 gmc sierra-3500hd
# https://www.edmunds.com/gmc/sierra-3500hd/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc sierra-3500hd
# -----------------------------------------------Checking for 2015 gmc terrain
# https://www.edmunds.com/gmc/terrain/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc terrain
# -----------------------------------------------Checking for 2015 buick envision
# https://www.edmunds.com/buick/envision/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 cadillac ats-v
# https://www.edmunds.com/cadillac/ats-v/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mazda cx-9
# https://www.edmunds.com/mazda/cx-9/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mazda cx-9
# -----------------------------------------------Checking for 2015 chevrolet cruze
# https://www.edmunds.com/chevrolet/cruze/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet cruze
# -----------------------------------------------Checking for 2015 ford escape
# https://www.edmunds.com/ford/escape/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford escape
# -----------------------------------------------Checking for 2015 lexus ct-200h
# https://www.edmunds.com/lexus/ct-200h/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final lexus ct-200h
# -----------------------------------------------Checking for 2015 bmw 3-series
# https://www.edmunds.com/bmw/3-series/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw 3-series
# -----------------------------------------------Checking for 2015 nissan versa
# https://www.edmunds.com/nissan/versa/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan versa
# -----------------------------------------------Checking for 2015 infiniti g35
# https://www.edmunds.com/infiniti/g35/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 bmw 7-series
# https://www.edmunds.com/bmw/7-series/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw 7-series
# -----------------------------------------------Checking for 2015 toyota camry-hybrid
# https://www.edmunds.com/toyota/camry-hybrid/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota camry-hybrid
# -----------------------------------------------Checking for 2015 saturn l-series
# https://www.edmunds.com/saturn/l-series/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota sienna
# https://www.edmunds.com/toyota/sienna/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota sienna
# -----------------------------------------------Checking for 2015 kia sportage
# https://www.edmunds.com/kia/sportage/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia sportage
# -----------------------------------------------Checking for 2015 toyota prius
# https://www.edmunds.com/toyota/prius/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota prius
# -----------------------------------------------Checking for 2015 subaru legacy
# https://www.edmunds.com/subaru/legacy/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final subaru legacy
# -----------------------------------------------Checking for 2015 nissan versa-note
# https://www.edmunds.com/nissan/versa-note/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan versa-note
# -----------------------------------------------Checking for 2015 mini cooper-clubman
# https://www.edmunds.com/mini/cooper-clubman/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota land-cruiser
# https://www.edmunds.com/toyota/land-cruiser/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota land-cruiser
# -----------------------------------------------Checking for 2015 honda accord
# https://www.edmunds.com/honda/accord/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda accord
# -----------------------------------------------Checking for 2015 scion tc
# https://www.edmunds.com/scion/tc/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final scion tc
# -----------------------------------------------Checking for 2015 mercedesbenz cls-class
# https://www.edmunds.com/mercedesbenz/cls-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz cls-class
# -----------------------------------------------Checking for 2015 mercedesbenz metris
# https://www.edmunds.com/mercedesbenz/metris/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 chevrolet spark
# https://www.edmunds.com/chevrolet/spark/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet spark
# -----------------------------------------------Checking for 2015 bmw x3
# https://www.edmunds.com/bmw/x3/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw x3
# -----------------------------------------------Checking for 2015 honda pilot
# https://www.edmunds.com/honda/pilot/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda pilot
# -----------------------------------------------Checking for 2015 toyota 4runner
# https://www.edmunds.com/toyota/4runner/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota 4runner
# -----------------------------------------------Checking for 2015 toyota corolla
# https://www.edmunds.com/toyota/corolla/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota corolla
# -----------------------------------------------Checking for 2015 nissan leaf
# https://www.edmunds.com/nissan/leaf/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan leaf
# -----------------------------------------------Checking for 2015 ford ranger
# https://www.edmunds.com/ford/ranger/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford flex
# https://www.edmunds.com/ford/flex/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford flex
# -----------------------------------------------Checking for 2015 toyota matrix
# https://www.edmunds.com/toyota/matrix/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mitsubishi mirage
# https://www.edmunds.com/mitsubishi/mirage/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mitsubishi mirage
# -----------------------------------------------Checking for 2015 ram 1500
# https://www.edmunds.com/ram/1500/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ram 1500
# -----------------------------------------------Checking for 2015 chevrolet s-10
# https://www.edmunds.com/chevrolet/s-10/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 chrysler pacifica
# https://www.edmunds.com/chrysler/pacifica/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 dodge grand-caravan
# https://www.edmunds.com/dodge/grand-caravan/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final dodge grand-caravan
# -----------------------------------------------Checking for 2015 ford five-hundred
# https://www.edmunds.com/ford/five-hundred/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 volvo s60
# https://www.edmunds.com/volvo/s60/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volvo s60
# -----------------------------------------------Checking for 2015 chevrolet cobalt
# https://www.edmunds.com/chevrolet/cobalt/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 volkswagen tiguan
# https://www.edmunds.com/volkswagen/tiguan/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volkswagen tiguan
# -----------------------------------------------Checking for 2015 ford expedition
# https://www.edmunds.com/ford/expedition/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford expedition
# -----------------------------------------------Checking for 2015 lexus lx-570
# https://www.edmunds.com/lexus/lx-570/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final lexus lx-570
# -----------------------------------------------Checking for 2015 kia optima
# https://www.edmunds.com/kia/optima/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia optima
# -----------------------------------------------Checking for 2015 mercedesbenz cla-class
# https://www.edmunds.com/mercedesbenz/cla-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz cla-class
# -----------------------------------------------Checking for 2015 chevrolet hhr
# https://www.edmunds.com/chevrolet/hhr/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 chevrolet trax
# https://www.edmunds.com/chevrolet/trax/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet trax
# -----------------------------------------------Checking for 2015 mitsubishi outlander-sport
# https://www.edmunds.com/mitsubishi/outlander-sport/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mitsubishi outlander-sport
# -----------------------------------------------Checking for 2015 volvo xc60
# https://www.edmunds.com/volvo/xc60/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volvo xc60
# -----------------------------------------------Checking for 2015 chevrolet silverado-1500
# https://www.edmunds.com/chevrolet/silverado-1500/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet silverado-1500
# -----------------------------------------------Checking for 2015 chevrolet traverse
# https://www.edmunds.com/chevrolet/traverse/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet traverse
# -----------------------------------------------Checking for 2015 jeep wrangler
# https://www.edmunds.com/jeep/wrangler/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jeep wrangler
# -----------------------------------------------Checking for 2015 honda cr-v
# https://www.edmunds.com/honda/cr-v/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda cr-v
# -----------------------------------------------Checking for 2015 cadillac ct6
# https://www.edmunds.com/cadillac/ct6/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 kia rio
# https://www.edmunds.com/kia/rio/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia rio
# -----------------------------------------------Checking for 2015 nissan altima
# https://www.edmunds.com/nissan/altima/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan altima
# -----------------------------------------------Checking for 2015 toyota highlander
# https://www.edmunds.com/toyota/highlander/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota highlander
# -----------------------------------------------Checking for 2015 fiat 500x
# https://www.edmunds.com/fiat/500x/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 acura rlx
# https://www.edmunds.com/acura/rlx/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final acura rlx
# -----------------------------------------------Checking for 2015 audi a6
# https://www.edmunds.com/audi/a6/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final audi a6
# -----------------------------------------------Checking for 2015 buick encore
# https://www.edmunds.com/buick/encore/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final buick encore
# -----------------------------------------------Checking for 2015 ford explorer
# https://www.edmunds.com/ford/explorer/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford explorer
# -----------------------------------------------Checking for 2015 mazda 2
# https://www.edmunds.com/mazda/2/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 infiniti m35
# https://www.edmunds.com/infiniti/m35/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 saturn ion
# https://www.edmunds.com/saturn/ion/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 kia sedona
# https://www.edmunds.com/kia/sedona/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final kia sedona
# -----------------------------------------------Checking for 2015 honda fit
# https://www.edmunds.com/honda/fit/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda fit
# -----------------------------------------------Checking for 2015 bmw 5-series
# https://www.edmunds.com/bmw/5-series/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw 5-series
# -----------------------------------------------Checking for 2015 hyundai santa-fe-sport
# https://www.edmunds.com/hyundai/santa-fe-sport/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai santa-fe-sport
# -----------------------------------------------Checking for 2015 subaru impreza
# https://www.edmunds.com/subaru/impreza/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final subaru impreza
# -----------------------------------------------Checking for 2015 saturn vue
# https://www.edmunds.com/saturn/vue/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 cadillac ats
# https://www.edmunds.com/cadillac/ats/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final cadillac ats
# -----------------------------------------------Checking for 2015 acura mdx
# https://www.edmunds.com/acura/mdx/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final acura mdx
# -----------------------------------------------Checking for 2015 chrysler 200
# https://www.edmunds.com/chrysler/200/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chrysler 200
# -----------------------------------------------Checking for 2015 chrysler 300
# https://www.edmunds.com/chrysler/300/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chrysler 300
# -----------------------------------------------Checking for 2015 lexus es-300
# https://www.edmunds.com/lexus/es-300/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 volkswagen passat
# https://www.edmunds.com/volkswagen/passat/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volkswagen passat
# -----------------------------------------------Checking for 2015 ford mustang
# https://www.edmunds.com/ford/mustang/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford mustang
# -----------------------------------------------Checking for 2015 mercedesbenz slk-class
# https://www.edmunds.com/mercedesbenz/slk-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz slk-class
# -----------------------------------------------Checking for 2015 fiat 500
# https://www.edmunds.com/fiat/500/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final fiat 500
# -----------------------------------------------Checking for 2015 ford fusion
# https://www.edmunds.com/ford/fusion/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford fusion
# -----------------------------------------------Checking for 2015 nissan armada
# https://www.edmunds.com/nissan/armada/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan armada
# -----------------------------------------------Checking for 2015 hyundai tiburon
# https://www.edmunds.com/hyundai/tiburon/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 bmw i3
# https://www.edmunds.com/bmw/i3/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw i3
# -----------------------------------------------Checking for 2015 toyota camry
# https://www.edmunds.com/toyota/camry/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota camry
# -----------------------------------------------Checking for 2015 chevrolet suburban
# https://www.edmunds.com/chevrolet/suburban/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet suburban
# -----------------------------------------------Checking for 2015 audi a4
# https://www.edmunds.com/audi/a4/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final audi a4
# -----------------------------------------------Checking for 2015 cadillac sts
# https://www.edmunds.com/cadillac/sts/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 nissan murano
# https://www.edmunds.com/nissan/murano/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan murano
# -----------------------------------------------Checking for 2015 volkswagen new-beetle
# https://www.edmunds.com/volkswagen/new-beetle/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 nissan rogue-sport
# https://www.edmunds.com/nissan/rogue-sport/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 nissan rogue
# https://www.edmunds.com/nissan/rogue/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan rogue
# -----------------------------------------------Checking for 2015 toyota yaris
# https://www.edmunds.com/toyota/yaris/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota yaris
# -----------------------------------------------Checking for 2015 mini cooper-paceman
# https://www.edmunds.com/mini/cooper-paceman/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mini cooper-paceman
# -----------------------------------------------Checking for 2015 acura rdx
# https://www.edmunds.com/acura/rdx/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final acura rdx
# -----------------------------------------------Checking for 2015 chevrolet camaro
# https://www.edmunds.com/chevrolet/camaro/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet camaro
# -----------------------------------------------Checking for 2015 gmc canyon
# https://www.edmunds.com/gmc/canyon/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc canyon
# -----------------------------------------------Checking for 2015 landrover range-rover-evoque
# https://www.edmunds.com/landrover/range-rover-evoque/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final landrover range-rover-evoque
# -----------------------------------------------Checking for 2015 mitsubishi mirage-g4
# https://www.edmunds.com/mitsubishi/mirage-g4/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 gmc sierra-1500
# https://www.edmunds.com/gmc/sierra-1500/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc sierra-1500
# -----------------------------------------------Checking for 2015 honda odyssey
# https://www.edmunds.com/honda/odyssey/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda odyssey
# -----------------------------------------------Checking for 2015 ferrari 458-italia
# https://www.edmunds.com/ferrari/458-italia/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 porsche 911
# https://www.edmunds.com/porsche/cayenne/2015/st-200707125/cost-to-own/
# ---------------------Record inserted successfully for 2015_final porsche 911
# -----------------------------------------------Checking for 2015 pontiac sunfire
# https://www.edmunds.com/pontiac/sunfire/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz glk-class
# https://www.edmunds.com/mercedesbenz/glk-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz glk-class
# -----------------------------------------------Checking for 2015 infiniti qx60
# https://www.edmunds.com/infiniti/qx60/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final infiniti qx60
# -----------------------------------------------Checking for 2015 landrover range-rover
# https://www.edmunds.com/landrover/range-rover/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final landrover range-rover
# -----------------------------------------------Checking for 2015 lexus rx-330
# https://www.edmunds.com/lexus/rx-330/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 gmc yukon
# https://www.edmunds.com/gmc/yukon/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc yukon
# -----------------------------------------------Checking for 2015 audi s5
# https://www.edmunds.com/audi/s5/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final audi s5
# -----------------------------------------------Checking for 2015 mercedesbenz s-class
# https://www.edmunds.com/mercedesbenz/s-class/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 bmw 6-series
# https://www.edmunds.com/bmw/6-series/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final bmw 6-series
# -----------------------------------------------Checking for 2015 dodge viper
# https://www.edmunds.com/dodge/viper/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 bmw i8
# https://www.edmunds.com/bmw/i8/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz g-class
# https://www.edmunds.com/mercedesbenz/g-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz g-class
# -----------------------------------------------Checking for 2015 lexus lc-500
# https://www.edmunds.com/lexus/lc-500/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz sls-amg
# https://www.edmunds.com/mercedesbenz/sls-amg/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota prius-c
# https://www.edmunds.com/toyota/prius-c/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota prius-c
# -----------------------------------------------Checking for 2015 landrover range-rover-sport
# https://www.edmunds.com/landrover/range-rover-sport/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final landrover range-rover-sport
# -----------------------------------------------Checking for 2015 toyota prius-v
# https://www.edmunds.com/toyota/prius-v/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota prius-v
# -----------------------------------------------Checking for 2015 toyota corolla-im
# https://www.edmunds.com/toyota/corolla-im/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 jeep renegade
# https://www.edmunds.com/jeep/renegade/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jeep renegade
# -----------------------------------------------Checking for 2015 toyota avalon
# https://www.edmunds.com/toyota/avalon/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota avalon
# -----------------------------------------------Checking for 2015 rolls-royce dawn
# https://www.edmunds.com/rolls-royce/dawn/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 rolls-royce ghost
# https://www.edmunds.com/rolls-royce/ghost/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 rolls-royce ghost-series-ii
# https://www.edmunds.com/rolls-royce/ghost-series-ii/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 rolls-royce wraith
# https://www.edmunds.com/rolls-royce/wraith/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 rolls-royce phantom-drophead-coupe
# https://www.edmunds.com/rolls-royce/phantom-drophead-coupe/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz sls-amg-gt-final-edition
# https://www.edmunds.com/mercedesbenz/sls-amg-gt-final-edition/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ferrari 599
# https://www.edmunds.com/ferrari/599/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ferrari f430
# https://www.edmunds.com/ferrari/f430/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ferrari california
# https://www.edmunds.com/ferrari/california/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz c-class
# https://www.edmunds.com/mercedesbenz/c-class/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mercedesbenz c-class
# -----------------------------------------------Checking for 2015 lexus es-330
# https://www.edmunds.com/lexus/es-330/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 volkswagen golf-gti
# https://www.edmunds.com/volkswagen/golf-gti/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final volkswagen golf-gti
# -----------------------------------------------Checking for 2015 volkswagen jetta-sportwagen
# https://www.edmunds.com/volkswagen/jetta-sportwagen/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford transit-wagon
# https://www.edmunds.com/ford/transit-wagon/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford transit-van
# https://www.edmunds.com/ford/transit-van/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 pontiac trans-sport
# https://www.edmunds.com/pontiac/trans-sport/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 gmc savana-cargo
# https://www.edmunds.com/gmc/savana-cargo/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final gmc savana-cargo
# -----------------------------------------------Checking for 2015 subaru forester
# https://www.edmunds.com/subaru/forester/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final subaru forester
# -----------------------------------------------Checking for 2015 infiniti g37
# https://www.edmunds.com/infiniti/g37/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz sl-class
# https://www.edmunds.com/mercedesbenz/sl-class/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mercedesbenz clk-class
# https://www.edmunds.com/mercedesbenz/clk-class/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 mini cooper
# https://www.edmunds.com/mini/cooper/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final mini cooper
# -----------------------------------------------Checking for 2015 infiniti g-coupe
# https://www.edmunds.com/infiniti/g-coupe/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 kia soul-ev
# https://www.edmunds.com/kia/soul-ev/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota fj-cruiser
# https://www.edmunds.com/toyota/fj-cruiser/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 hyundai veloster
# https://www.edmunds.com/hyundai/veloster/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final hyundai veloster
# -----------------------------------------------Checking for 2015 honda cr-z
# https://www.edmunds.com/honda/cr-z/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final honda cr-z
# -----------------------------------------------Checking for 2015 mazda cx-3
# https://www.edmunds.com/mazda/cx-3/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 chevrolet impala
# https://www.edmunds.com/chevrolet/impala/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet impala
# -----------------------------------------------Checking for 2015 cadillac dts
# https://www.edmunds.com/cadillac/dts/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford fusion-energi
# https://www.edmunds.com/ford/fusion-energi/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford fusion-energi
# -----------------------------------------------Checking for 2015 lexus nx-200t
# https://www.edmunds.com/lexus/nx-200t/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final lexus nx-200t
# -----------------------------------------------Checking for 2015 ford focus-rs
# https://www.edmunds.com/ford/focus-rs/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford fusion-hybrid
# https://www.edmunds.com/ford/fusion-hybrid/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford fusion-hybrid
# -----------------------------------------------Checking for 2015 chevrolet volt
# https://www.edmunds.com/chevrolet/volt/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet volt
# -----------------------------------------------Checking for 2015 ford f-350-super-duty
# https://www.edmunds.com/ford/f-350-super-duty/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford f-350-super-duty
# -----------------------------------------------Checking for 2015 toyota tacoma
# https://www.edmunds.com/toyota/tacoma/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final toyota tacoma
# -----------------------------------------------Checking for 2015 chevrolet tahoe
# https://www.edmunds.com/chevrolet/tahoe/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet tahoe
# -----------------------------------------------Checking for 2015 ford edge
# https://www.edmunds.com/ford/edge/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford edge
# -----------------------------------------------Checking for 2015 lexus rx-350
# https://www.edmunds.com/lexus/rx-350/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final lexus rx-350
# -----------------------------------------------Checking for 2015 cadillac srx
# https://www.edmunds.com/cadillac/srx/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final cadillac srx
# -----------------------------------------------Checking for 2015 nissan frontier
# https://www.edmunds.com/nissan/frontier/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final nissan frontier
# -----------------------------------------------Checking for 2015 ford f-250-super-duty
# https://www.edmunds.com/ford/f-250-super-duty/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford f-250-super-duty
# -----------------------------------------------Checking for 2015 dodge durango
# https://www.edmunds.com/dodge/durango/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final dodge durango
# -----------------------------------------------Checking for 2015 ford ecosport
# https://www.edmunds.com/ford/ecosport/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 ford taurus
# https://www.edmunds.com/ford/taurus/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford taurus
# -----------------------------------------------Checking for 2015 ford c-max-hybrid
# https://www.edmunds.com/ford/c-max-hybrid/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford c-max-hybrid
# -----------------------------------------------Checking for 2015 ford transit-connect
# https://www.edmunds.com/ford/transit-connect/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford transit-connect
# -----------------------------------------------Checking for 2015 ford focus-st
# https://www.edmunds.com/ford/focus-st/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final ford focus-st
# -----------------------------------------------Checking for 2015 jeep cherokee
# https://www.edmunds.com/jeep/cherokee/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final jeep cherokee
# -----------------------------------------------Checking for 2015 chevrolet corvette
# https://www.edmunds.com/chevrolet/corvette/2015/cost-to-own/
# ---------------------Record inserted successfully for 2015_final chevrolet corvette
# -----------------------------------------------Checking for 2015 lexus gx-470
# https://www.edmunds.com/lexus/gx-470/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota rav4-hybrid
# https://www.edmunds.com/toyota/rav4-hybrid/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota prius-prime
# https://www.edmunds.com/toyota/prius-prime/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota 86
# https://www.edmunds.com/toyota/86/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota yaris-ia
# https://www.edmunds.com/toyota/yaris-ia/2015/cost-to-own/
# -----------------------------------------------Checking for 2015 toyota corolla-hatchback
# https://www.edmunds.com/toyota/corolla-hatchback/2015/cost-to-own/

# %%
db.rrecord.renameCollection("record")

mongoexport --db FinalProject --collection 2015 --out 2015.json
